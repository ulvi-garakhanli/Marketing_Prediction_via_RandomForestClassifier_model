# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # PRE_PROCESING
#
#
# ## Upload Data

# %%
pd.set_option('display.max_columns',40)

data = pd.read_csv(r'marketing.csv')
data
# Out:
#           ID  age         job  marital  education default  balance housing  \
# 0      13829   29  technician   single   tertiary      no    18254      no
# 1      22677   26    services   single  secondary      no      512     yes
# 2      10541   30  management   single  secondary      no      135      no
# 3      13689   41  technician  married    unknown      no       30     yes
# 4      11304   27      admin.   single  secondary      no      321      no
# ...      ...  ...         ...      ...        ...     ...      ...     ...
# 12865  14023   47  technician  married  secondary      no     1167     yes
# 12866  17259   31     unknown  married  secondary      no      111      no
# 12867  15200   37  unemployed   single   tertiary      no     1316     yes
# 12868  13775   42  management  married   tertiary      no      479     yes
# 12869  20137   24    services   single  secondary      no        0      no
#
#       loan   contact  day month  campaign  pdays  previous response result
# 0       no  cellular   11   may         2     -1         0  unknown     no
# 1      yes   unknown    5   jun         3     -1         0  unknown     no
# 2       no  cellular   14   aug         2     -1         0  unknown     no
# 3       no  cellular   10   jul         1     -1         0  unknown     no
# 4      yes   unknown    2   sep         1     -1         0  unknown     no
# ...    ...       ...  ...   ...       ...    ...       ...      ...    ...
# 12865   no  cellular   30   apr         1     87         5  failure    yes
# 12866   no  cellular   21   nov         2     93         2  failure    yes
# 12867   no  cellular   18   nov         1    172         2  failure     no
# 12868   no   unknown   28   may         2     -1         0  unknown     no
# 12869   no   unknown   16   may         1     -1         0  unknown     no
#
# [12870 rows x 17 columns]

# %% [markdown]
# ## Describe all columns

# %%
data.describe(include='all')
# Out:
#                   ID           age         job  marital  education default  \
# count   12870.000000  12870.000000       12870    12870      12870   12870
# unique           NaN           NaN          12        3          4       2
# top              NaN           NaN  management  married  secondary      no
# freq             NaN           NaN        2858     7490       6368   12662
# mean    16434.500000     41.091142         NaN      NaN        NaN     NaN
# std      3715.393317     11.305560         NaN      NaN        NaN     NaN
# min     10000.000000     18.000000         NaN      NaN        NaN     NaN
# 25%     13217.250000     32.000000         NaN      NaN        NaN     NaN
# 50%     16434.500000     39.000000         NaN      NaN        NaN     NaN
# 75%     19651.750000     49.000000         NaN      NaN        NaN     NaN
# max     22869.000000     95.000000         NaN      NaN        NaN     NaN
#
#               balance housing   loan   contact           day  month  \
# count    12870.000000   12870  12870     12870  12870.000000  12870
# unique            NaN       2      2         3           NaN     12
# top               NaN     yes     no  cellular           NaN    may
# freq              NaN    6605  11060      8756           NaN   3594
# mean      1483.774437     NaN    NaN       NaN     15.641103    NaN
# std       3311.055181     NaN    NaN       NaN      8.368983    NaN
# min      -6847.000000     NaN    NaN       NaN      1.000000    NaN
# 25%        102.000000     NaN    NaN       NaN      8.000000    NaN
# 50%        515.000000     NaN    NaN       NaN     16.000000    NaN
# 75%       1591.750000     NaN    NaN       NaN     21.000000    NaN
# max     102127.000000     NaN    NaN       NaN     31.000000    NaN
#
#             campaign         pdays      previous response result
# count   12870.000000  12870.000000  12870.000000    12870  12870
# unique           NaN           NaN           NaN        4      2
# top              NaN           NaN           NaN  unknown     no
# freq             NaN           NaN           NaN    10070   8903
# mean        2.659130     45.555478      0.688967      NaN    NaN
# std         2.863507    104.449411      2.049696      NaN    NaN
# min         1.000000     -1.000000      0.000000      NaN    NaN
# 25%         1.000000     -1.000000      0.000000      NaN    NaN
# 50%         2.000000     -1.000000      0.000000      NaN    NaN
# 75%         3.000000     -1.000000      0.000000      NaN    NaN
# max        43.000000    854.000000     58.000000      NaN    NaN

# %% [markdown]
# ## Look if there is missing value

# %%
data.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# campaign     0
# pdays        0
# previous     0
# response     0
# result       0
# dtype: int64

# %% [markdown]
# ## Transform value of dependent into 1 and 0 using maping method

# %%
data['result'] = data['result'].map({'yes':0, 'no':1})

data
# Out:
#           ID  age         job  marital  education default  balance housing  \
# 0      13829   29  technician   single   tertiary      no    18254      no
# 1      22677   26    services   single  secondary      no      512     yes
# 2      10541   30  management   single  secondary      no      135      no
# 3      13689   41  technician  married    unknown      no       30     yes
# 4      11304   27      admin.   single  secondary      no      321      no
# ...      ...  ...         ...      ...        ...     ...      ...     ...
# 12865  14023   47  technician  married  secondary      no     1167     yes
# 12866  17259   31     unknown  married  secondary      no      111      no
# 12867  15200   37  unemployed   single   tertiary      no     1316     yes
# 12868  13775   42  management  married   tertiary      no      479     yes
# 12869  20137   24    services   single  secondary      no        0      no
#
#       loan   contact  day month  campaign  pdays  previous response  result
# 0       no  cellular   11   may         2     -1         0  unknown       1
# 1      yes   unknown    5   jun         3     -1         0  unknown       1
# 2       no  cellular   14   aug         2     -1         0  unknown       1
# 3       no  cellular   10   jul         1     -1         0  unknown       1
# 4      yes   unknown    2   sep         1     -1         0  unknown       1
# ...    ...       ...  ...   ...       ...    ...       ...      ...     ...
# 12865   no  cellular   30   apr         1     87         5  failure       0
# 12866   no  cellular   21   nov         2     93         2  failure       0
# 12867   no  cellular   18   nov         1    172         2  failure       1
# 12868   no   unknown   28   may         2     -1         0  unknown       1
# 12869   no   unknown   16   may         1     -1         0  unknown       1
#
# [12870 rows x 17 columns]

# %%
data.result.value_counts()
# Out:
# 1    8903
# 0    3967
# Name: result, dtype: int64

# %% [markdown]
# ## Look cerrelation

# %%
corr = data.corr()['result']

# select highly correlated features
high_corr = corr[abs(corr)>0.05].index.tolist()
high_corr
# Out:
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/2789285142.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()['result']
# ['balance', 'campaign', 'pdays', 'previous', 'result']

# %% [markdown]
# ## Use variance_infilation_factor to measure multicollinearity beetwen the independent variables

# %%
vari = data[['balance', 'campaign', 'pdays', 'previous']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(vari.values,i) for i in range(vari.shape[1])]
vif['Features'] = vari.columns
vif
# Out:
#         VIF  Features
# 0  1.098335   balance
# 1  1.111969  campaign
# 2  1.541053     pdays
# 3  1.523563  previous

# %% [markdown]
# ## Drop 'pdays' and 'previous' columns because of value counts

# %%
data.pdays.value_counts()
# Out:
# -1      10067
#  182       76
#  92        75
#  91        65
#  181       63
#         ...
#  440        1
#  804        1
#  434        1
#  437        1
#  427        1
# Name: pdays, Length: 461, dtype: int64

# %%
data.previous.value_counts()
# Out:
# 0     10067
# 1       921
# 2       692
# 3       391
# 4       248
# 5       182
# 6       109
# 7        60
# 8        54
# 9        28
# 10       28
# 12       20
# 11       18
# 13       11
# 14        6
# 17        6
# 16        4
# 15        4
# 20        4
# 19        2
# 21        2
# 23        2
# 29        2
# 30        2
# 18        2
# 26        1
# 37        1
# 22        1
# 58        1
# 55        1
# Name: previous, dtype: int64

# %%
data = data.drop(['pdays','previous'], axis=1)
data
# Out:
#           ID  age         job  marital  education default  balance housing  \
# 0      13829   29  technician   single   tertiary      no    18254      no
# 1      22677   26    services   single  secondary      no      512     yes
# 2      10541   30  management   single  secondary      no      135      no
# 3      13689   41  technician  married    unknown      no       30     yes
# 4      11304   27      admin.   single  secondary      no      321      no
# ...      ...  ...         ...      ...        ...     ...      ...     ...
# 12865  14023   47  technician  married  secondary      no     1167     yes
# 12866  17259   31     unknown  married  secondary      no      111      no
# 12867  15200   37  unemployed   single   tertiary      no     1316     yes
# 12868  13775   42  management  married   tertiary      no      479     yes
# 12869  20137   24    services   single  secondary      no        0      no
#
#       loan   contact  day month  campaign response  result
# 0       no  cellular   11   may         2  unknown       1
# 1      yes   unknown    5   jun         3  unknown       1
# 2       no  cellular   14   aug         2  unknown       1
# 3       no  cellular   10   jul         1  unknown       1
# 4      yes   unknown    2   sep         1  unknown       1
# ...    ...       ...  ...   ...       ...      ...     ...
# 12865   no  cellular   30   apr         1  failure       0
# 12866   no  cellular   21   nov         2  failure       0
# 12867   no  cellular   18   nov         1  failure       1
# 12868   no   unknown   28   may         2  unknown       1
# 12869   no   unknown   16   may         1  unknown       1
#
# [12870 rows x 15 columns]

# %% [markdown]
# ## Find out if there is Outlier

# %%
for i in data[['balance','campaign']]:
    sns.boxplot(data=data,x=data[i])
    plt.show()

# %% [markdown]
# ## Outlier treatment

# %%
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)
IQR = q3-q1

Lower = q1-1.5*IQR
Upper = q3+1.5*IQR
# Out:
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/59704685.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1 = data.quantile(0.25)
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/59704685.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3 = data.quantile(0.75)

# %%
for i in data[['balance','campaign']]:
    data[i]=np.where(data[i]>Upper[i],Upper[i],data[i])
    data[i]=np.where(data[i]<Lower[i],Lower[i],data[i])

# %%
for i in data[['balance','campaign']]:
    sns.boxplot(data=data,x=data[i])
    plt.show()

# %%
data.dtypes
# Out:
# ID             int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# campaign     float64
# response      object
# result         int64
# dtype: object

# %% [markdown]
# # WOE transformation:
#
# ## First we have to transform numeric columns to categorical and for that we are using quantile method.

# %% [markdown]
# ![hrTnEXv.jpg](attachment:hrTnEXv.jpg)

# %%
ranges = [ -np.inf, data['balance'].quantile(0.25), data['balance'].quantile(0.50), data['balance'].quantile(0.75), np.inf]
data['balance_category'] = pd.cut(data['balance'],bins=ranges)

grouped = data.groupby(['balance_category','result'])['result'].count().unstack().reset_index()
grouped['positive_prop']= grouped[0]/grouped[0].sum()
grouped['negative_prop']= grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'balance_woe'},inplace=True)
data = data.merge(grouped[['balance_category','balance_woe']],how='left', on='balance_category')

#data

# %%
ranges = [ -np.inf, data['campaign'].quantile(0.25), data['campaign'].quantile(0.50), data['campaign'].quantile(0.75), np.inf]
data['campaign_category'] = pd.cut(data['campaign'],bins=ranges)

grouped = data.groupby(['campaign_category','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'campaign_woe'},inplace=True)
data = data.merge(grouped[['campaign_category','campaign_woe']],how='left', on='campaign_category')

#data

# %%
grouped = data.groupby(['job','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'job_woe'},inplace=True)
data = data.merge(grouped[['job','job_woe']],how='left', on='job')

#data

# %%
grouped = data.groupby(['marital','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'marital_woe'},inplace=True)
data = data.merge(grouped[['marital','marital_woe']],how='left', on='marital')

#data

# %%
grouped = data.groupby(['education','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'education_woe'},inplace=True)
data = data.merge(grouped[['education','education_woe']],how='left', on='education')

#data

# %%
grouped = data.groupby(['default','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'default_woe'},inplace=True)
data = data.merge(grouped[['default','default_woe']],how='left', on='default')

#data

# %%
grouped = data.groupby(['housing','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'housing_woe'},inplace=True)
data = data.merge(grouped[['housing','housing_woe']],how='left', on='housing')

#data

# %%
grouped = data.groupby(['loan','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'loan_woe'},inplace=True)
data = data.merge(grouped[['loan','loan_woe']],how='left', on='loan')

#data

# %%
grouped = data.groupby(['contact','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'contact_woe'},inplace=True)
data = data.merge(grouped[['contact','contact_woe']],how='left', on='contact')

#data

# %%
grouped = data.groupby(['month','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'month_woe'},inplace=True)
data = data.merge(grouped[['month','month_woe']],how='left', on='month')

#data

# %%
grouped = data.groupby(['response','result'])['result'].count().unstack().reset_index()
grouped['positive_prop'] = grouped[0]/grouped[0].sum()
grouped['negative_prop'] = grouped[1]/grouped[1].sum()
grouped['woe'] = np.log(grouped['positive_prop']/grouped['negative_prop'])
grouped.rename(columns={'woe':'response_woe'},inplace=True)
data = data.merge(grouped[['response','response_woe']],how='left', on='response')

# %% [markdown]
# ### Or you can also write just one loop for woe transformation:

# %%
# num_variables = ['balance', 'campaign']

# for var in num_variables:
    # q1 = data[var].quantile(0.25)
    # q2 = data[var].quantile(0.5)
    # q3 = data[var].quantile(0.75)

    
    # ranges = [-np.inf, q1, q2, q3, np.inf]
    # data[var+'_category'] = pd.cut(data[var], bins=ranges,duplicates='drop')
    
    # grouped = data.groupby([var+'_category', 'result'])['result'].count().unstack().reset_index()
    

    # grouped['positive_prop'] = grouped[0] / grouped[0].sum()
    # grouped['negative_prop'] = grouped[1] / grouped[1].sum()
    
    # grouped['woe'] = np.log(grouped['positive_prop'] / grouped['negative_prop'])
    # grouped.rename(columns={'woe':var+'_woe'}, inplace=True)
    # data = data.merge(grouped[[var+'_category',var+'_woe']], how='left', on=var+'_category')

# %%
# cat_variables = ['job', 'marital', 'education', 'default','housing', 'loan', 'contact', 'month','response']

# for var in cat_variables:
    # grouped = data.groupby([var, 'result'])['result'].count().unstack().reset_index()

    # grouped['positive_prop'] = grouped[0] / grouped[0].sum()
    # grouped['negative_prop'] = grouped[1] / grouped[1].sum()

    # grouped['woe'] = np.log(grouped['positive_prop'] / grouped['negative_prop'])

    # grouped.rename(columns={'woe':var+'_woe'}, inplace=True)
    # data = data.merge(grouped[[var,var+'_woe']], how='left', on=var)

# %%
data
# Out:
#           ID  age         job  marital  education default   balance housing  \
# 0      13829   29  technician   single   tertiary      no  3826.375      no
# 1      22677   26    services   single  secondary      no   512.000     yes
# 2      10541   30  management   single  secondary      no   135.000      no
# 3      13689   41  technician  married    unknown      no    30.000     yes
# 4      11304   27      admin.   single  secondary      no   321.000      no
# ...      ...  ...         ...      ...        ...     ...       ...     ...
# 12865  14023   47  technician  married  secondary      no  1167.000     yes
# 12866  17259   31     unknown  married  secondary      no   111.000      no
# 12867  15200   37  unemployed   single   tertiary      no  1316.000     yes
# 12868  13775   42  management  married   tertiary      no   479.000     yes
# 12869  20137   24    services   single  secondary      no     0.000      no
#
#       loan   contact  day month  campaign response  result  balance_category  \
# 0       no  cellular   11   may       2.0  unknown       1    (1591.75, inf]
# 1      yes   unknown    5   jun       3.0  unknown       1    (102.0, 515.0]
# 2       no  cellular   14   aug       2.0  unknown       1    (102.0, 515.0]
# 3       no  cellular   10   jul       1.0  unknown       1     (-inf, 102.0]
# 4      yes   unknown    2   sep       1.0  unknown       1    (102.0, 515.0]
# ...    ...       ...  ...   ...       ...      ...     ...               ...
# 12865   no  cellular   30   apr       1.0  failure       0  (515.0, 1591.75]
# 12866   no  cellular   21   nov       2.0  failure       0    (102.0, 515.0]
# 12867   no  cellular   18   nov       1.0  failure       1  (515.0, 1591.75]
# 12868   no   unknown   28   may       2.0  unknown       1    (102.0, 515.0]
# 12869   no   unknown   16   may       1.0  unknown       1     (-inf, 102.0]
#
#        balance_woe campaign_category  campaign_woe   job_woe  marital_woe  \
# 0         0.396176        (1.0, 2.0]     -0.010317 -0.066429     0.275227
# 1        -0.036100        (2.0, 3.0]     -0.050576 -0.223585     0.275227
# 2        -0.036100        (1.0, 2.0]     -0.010317  0.161072     0.275227
# 3        -0.493008       (-inf, 1.0]      0.247182 -0.066429    -0.168233
# 4        -0.036100       (-inf, 1.0]      0.247182  0.018331     0.275227
# ...            ...               ...           ...       ...          ...
# 12865     0.056321       (-inf, 1.0]      0.247182 -0.066429    -0.168233
# 12866    -0.036100        (1.0, 2.0]     -0.010317  0.019921    -0.168233
# 12867     0.056321       (-inf, 1.0]      0.247182  0.284649     0.275227
# 12868    -0.036100        (1.0, 2.0]     -0.010317  0.161072    -0.168233
# 12869    -0.493008       (-inf, 1.0]      0.247182 -0.223585     0.275227
#
#        education_woe  default_woe  housing_woe  loan_woe  contact_woe  \
# 0           0.284837     0.009654     0.402913  0.081815     0.284130
# 1          -0.112864     0.009654    -0.450332 -0.577916    -1.106492
# 2          -0.112864     0.009654     0.402913  0.081815     0.284130
# 3           0.112487     0.009654    -0.450332  0.081815     0.284130
# 4          -0.112864     0.009654     0.402913 -0.577916    -1.106492
# ...              ...          ...          ...       ...          ...
# 12865      -0.112864     0.009654    -0.450332  0.081815     0.284130
# 12866      -0.112864     0.009654     0.402913  0.081815     0.284130
# 12867       0.284837     0.009654    -0.450332  0.081815     0.284130
# 12868       0.284837     0.009654    -0.450332  0.081815    -1.106492
# 12869      -0.112864     0.009654     0.402913  0.081815    -1.106492
#
#        month_woe  response_woe
# 0      -0.628775     -0.280460
# 1      -0.124481     -0.280460
# 2      -0.111781     -0.280460
# 3      -0.248969     -0.280460
# 4       1.839980     -0.280460
# ...          ...           ...
# 12865   0.658317      0.173374
# 12866  -0.146627      0.173374
# 12867  -0.146627      0.173374
# 12868  -0.628775     -0.280460
# 12869  -0.628775     -0.280460
#
# [12870 rows x 28 columns]

# %% [markdown]
# ## After WOE transformation we checking again if there is missing value

# %%
data.isnull().sum()
# Out:
# ID                   0
# age                  0
# job                  0
# marital              0
# education            0
# default              0
# balance              0
# housing              0
# loan                 0
# contact              0
# day                  0
# month                0
# campaign             0
# response             0
# result               0
# balance_category     0
# balance_woe          0
# campaign_category    0
# campaign_woe         0
# job_woe              0
# marital_woe          0
# education_woe        0
# default_woe          0
# housing_woe          0
# loan_woe             0
# contact_woe          0
# month_woe            0
# response_woe         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'response',
#        'result', 'balance_category', 'balance_woe', 'campaign_category',
#        'campaign_woe', 'job_woe', 'marital_woe', 'education_woe',
#        'default_woe', 'housing_woe', 'loan_woe', 'contact_woe', 'month_woe',
#        'response_woe'],
#       dtype='object')

# %% [markdown]
# ## Final data after pre processing

# %%
fin_data = data[['job', 'marital', 'education', 'default', 'balance',
       'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'response',
       'balance_category', 'balance_woe', 'campaign_category',
       'campaign_woe', 'job_woe', 'marital_woe', 'education_woe',
       'default_woe', 'housing_woe', 'loan_woe', 'contact_woe', 'month_woe',
       'response_woe','result']]
fin_data
# Out:
#               job  marital  education default   balance housing loan  \
# 0      technician   single   tertiary      no  3826.375      no   no
# 1        services   single  secondary      no   512.000     yes  yes
# 2      management   single  secondary      no   135.000      no   no
# 3      technician  married    unknown      no    30.000     yes   no
# 4          admin.   single  secondary      no   321.000      no  yes
# ...           ...      ...        ...     ...       ...     ...  ...
# 12865  technician  married  secondary      no  1167.000     yes   no
# 12866     unknown  married  secondary      no   111.000      no   no
# 12867  unemployed   single   tertiary      no  1316.000     yes   no
# 12868  management  married   tertiary      no   479.000     yes   no
# 12869    services   single  secondary      no     0.000      no   no
#
#         contact  day month  campaign response  balance_category  balance_woe  \
# 0      cellular   11   may       2.0  unknown    (1591.75, inf]     0.396176
# 1       unknown    5   jun       3.0  unknown    (102.0, 515.0]    -0.036100
# 2      cellular   14   aug       2.0  unknown    (102.0, 515.0]    -0.036100
# 3      cellular   10   jul       1.0  unknown     (-inf, 102.0]    -0.493008
# 4       unknown    2   sep       1.0  unknown    (102.0, 515.0]    -0.036100
# ...         ...  ...   ...       ...      ...               ...          ...
# 12865  cellular   30   apr       1.0  failure  (515.0, 1591.75]     0.056321
# 12866  cellular   21   nov       2.0  failure    (102.0, 515.0]    -0.036100
# 12867  cellular   18   nov       1.0  failure  (515.0, 1591.75]     0.056321
# 12868   unknown   28   may       2.0  unknown    (102.0, 515.0]    -0.036100
# 12869   unknown   16   may       1.0  unknown     (-inf, 102.0]    -0.493008
#
#       campaign_category  campaign_woe   job_woe  marital_woe  education_woe  \
# 0            (1.0, 2.0]     -0.010317 -0.066429     0.275227       0.284837
# 1            (2.0, 3.0]     -0.050576 -0.223585     0.275227      -0.112864
# 2            (1.0, 2.0]     -0.010317  0.161072     0.275227      -0.112864
# 3           (-inf, 1.0]      0.247182 -0.066429    -0.168233       0.112487
# 4           (-inf, 1.0]      0.247182  0.018331     0.275227      -0.112864
# ...                 ...           ...       ...          ...            ...
# 12865       (-inf, 1.0]      0.247182 -0.066429    -0.168233      -0.112864
# 12866        (1.0, 2.0]     -0.010317  0.019921    -0.168233      -0.112864
# 12867       (-inf, 1.0]      0.247182  0.284649     0.275227       0.284837
# 12868        (1.0, 2.0]     -0.010317  0.161072    -0.168233       0.284837
# 12869       (-inf, 1.0]      0.247182 -0.223585     0.275227      -0.112864
#
#        default_woe  housing_woe  loan_woe  contact_woe  month_woe  \
# 0         0.009654     0.402913  0.081815     0.284130  -0.628775
# 1         0.009654    -0.450332 -0.577916    -1.106492  -0.124481
# 2         0.009654     0.402913  0.081815     0.284130  -0.111781
# 3         0.009654    -0.450332  0.081815     0.284130  -0.248969
# 4         0.009654     0.402913 -0.577916    -1.106492   1.839980
# ...            ...          ...       ...          ...        ...
# 12865     0.009654    -0.450332  0.081815     0.284130   0.658317
# 12866     0.009654     0.402913  0.081815     0.284130  -0.146627
# 12867     0.009654    -0.450332  0.081815     0.284130  -0.146627
# 12868     0.009654    -0.450332  0.081815    -1.106492  -0.628775
# 12869     0.009654     0.402913  0.081815    -1.106492  -0.628775
#
#        response_woe  result
# 0         -0.280460       1
# 1         -0.280460       1
# 2         -0.280460       1
# 3         -0.280460       1
# 4         -0.280460       1
# ...             ...     ...
# 12865      0.173374       0
# 12866      0.173374       0
# 12867      0.173374       1
# 12868     -0.280460       1
# 12869     -0.280460       1
#
# [12870 rows x 26 columns]

# %% [markdown]
# # MODELLING
#
#
# ## Inputs and output

# %%
inputs = fin_data[['balance_woe','campaign_woe', 'job_woe', 'marital_woe', 'education_woe',
       'default_woe', 'housing_woe', 'loan_woe', 'contact_woe', 'month_woe',
       'response_woe']]
output = fin_data['result']

# %% [markdown]
# ## Train test split

# %%
X_train,X_test,y_train,y_test = train_test_split(inputs,output,test_size=0.3,random_state=42)

# %% [markdown]
# # Default model
#
#
# ## Create function to measure Gini

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
def evaluate(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:,1]

    roc_pred = roc_auc_score(y_test, y_pred)
    roc_prob = roc_auc_score(y_test, y_prob)
    
    gini_pred = roc_pred*2-1
    gini_prob = roc_prob*2-1
    
    print('Model Performance')

    print('Gini pred is', gini_pred*100)
    print('Gini prob is', gini_prob*100)
    
    return gini_pred
    return gini_prob

# %% [markdown]
# ## Fit our model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
base_model = RandomForestClassifier()
base_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Look our Default model's performance

# %%
base_mod_accuracy = evaluate(base_model,X_test,y_test)
# Out:
# Model Performance
# Gini pred is 32.66735853888818
# Gini prob is 44.59533757120997

# %% [markdown]
# # Optimization model
#
#
# ## Create function to select best estimators

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators= [int(x) for x in np.linspace(start = 100, stop = 2000, num = 20)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 20)]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,4]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 15, 20, 25, 31, 36, 41, 46, 52, 57, 62, 67, 73, 78, 83, 88, 94, 99, 104, 110], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}

# %% [markdown]
# ## Fit model

# %%
base_model_random = RandomizedSearchCV(estimator = base_model, param_distributions = random_grid, n_iter = 100, cv = 3, random_state=42, n_jobs = -1)

base_model_random.fit(X_train,y_train)
# Out:
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/ulvigarakhanli/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 15, 20, 25, 31, 36,
#                                                       41, 46, 52, 57, 62, 67,
#                                                       73, 78, 83, 88, 94, 99,
#                                                       104, 110],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100, 1200,
#                                                          1300, 1400, 1500, 1600,
#                                                          1700, 1800, 1900,
#                                                          2000]},
#                    random_state=42)

# %% [markdown]
# ## Look best estimators

# %%
base_model_random.best_params_
# Out:
# {'n_estimators': 900,
#  'min_samples_split': 2,
#  'min_samples_leaf': 4,
#  'max_features': 'sqrt',
#  'max_depth': 78}

# %% [markdown]
# ## Optimized model performance

# %%
optimized_model = base_model_random.best_estimator_
optmized_accuracy = evaluate(optimized_model, X_test, y_test)
# Out:
# Model Performance
# Gini pred is 34.655248863762324
# Gini prob is 51.9518314227212

# %% [markdown]
# ## Create roc curve graph to compare base_model and optimized_model

# %%
y_prob = base_model.predict_proba(X_test)[:,1]

roc_auc = roc_auc_score(y_test, y_prob)
gini = (2*roc_auc_score(y_test, y_prob))-1

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure()

plt.plot(fpr, tpr, label='(Roc_Auc = %0.2f)' % roc_auc)
plt.plot(fpr, tpr, label='(Gini = %0.2f)' % gini)
plt.plot([0, 1], [0, 1])
plt.xlim()
plt.ylim()

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

plt.legend(loc='lower right')
plt.show()

# %%
y_prob = optimized_model.predict_proba(X_test)[:,1]

roc_auc = roc_auc_score(y_test, y_prob)
gini = (2*roc_auc_score(y_test, y_prob))-1

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure()

plt.plot(fpr, tpr, label='(Roc_Auc = %0.2f)' % roc_auc)
plt.plot(fpr, tpr, label='(Gini = %0.2f)' % gini)
plt.plot([0, 1], [0, 1])
plt.xlim()
plt.ylim()

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # DEPLOYMENT
#
#
# ## Our optimized model showed higher Gini coefficient given 52%, hence we will deploy our trained model on new marketing data

# %%
test_data = pd.read_excel(r'marketing_test.xlsx')
test_data
# Out:
#       ID  age          job   marital  education default  balance housing loan  \
# 0    812   25  blue-collar    single  secondary      no      764     yes   no
# 1     71   40  blue-collar    single    primary      no      118      no   no
# 2    912   27       admin.  divorced  secondary      no      451     yes   no
# 3     43   30     services    single  secondary      no      495     yes   no
# 4    431   36  blue-collar   married    primary      no     1548     yes  yes
# ..   ...  ...          ...       ...        ...     ...      ...     ...  ...
# 852   49   43  blue-collar   married  secondary      no      413     yes   no
# 853  409   56   management   married   tertiary      no     1282      no   no
# 854  105   54       admin.   married    primary      no      976     yes   no
# 855  810   30   unemployed    single   tertiary      no     1159      no   no
# 856  410   52  blue-collar   married  secondary      no     1860      no   no
#
#        contact  day month  campaign  pdays  previous response
# 0     cellular   18   may         1     -1         0  unknown
# 1      unknown   23   feb         1     -1         0  unknown
# 2     cellular   16   jul         1     -1         0  unknown
# 3     cellular   21   nov         1     -1         0  unknown
# 4     cellular   18   may         2     -1         0  unknown
# ..         ...  ...   ...       ...    ...       ...      ...
# 852   cellular   12   aug         2    182         4  success
# 853   cellular   19   aug         4     -1         0  unknown
# 854    unknown    3   jun         3     -1         0  unknown
# 855  telephone    5   jun         1     -1         0  unknown
# 856    unknown   20   jun         3     -1         0  unknown
#
# [857 rows x 16 columns]

# %%
X_train
# Out:
#        balance_woe  campaign_woe   job_woe  marital_woe  education_woe  \
# 10678    -0.493008     -0.534710  0.018331     0.275227      -0.112864
# 5635      0.396176     -0.534710 -0.551866    -0.168233      -0.112864
# 9343      0.396176      0.247182  0.018331     0.275227      -0.112864
# 4581     -0.493008      0.247182 -0.551866    -0.168233      -0.112864
# 12117     0.056321     -0.534710 -0.551866    -0.168233      -0.112864
# ...            ...           ...       ...          ...            ...
# 11964     0.396176      0.247182  0.161072    -0.168233      -0.112864
# 5191      0.056321     -0.050576  0.161072    -0.168233       0.284837
# 5390     -0.036100     -0.010317 -0.551866    -0.168233      -0.330354
# 860      -0.036100     -0.534710 -0.066429    -0.168233      -0.112864
# 7270      0.056321     -0.050576  0.041619     0.275227       0.284837
#
#        default_woe  housing_woe  loan_woe  contact_woe  month_woe  \
# 10678     0.009654    -0.450332  0.081815    -1.106492  -0.628775
# 5635      0.009654    -0.450332  0.081815    -1.106492  -0.628775
# 9343      0.009654     0.402913  0.081815     0.284130   1.839980
# 4581      0.009654    -0.450332  0.081815    -1.106492  -0.628775
# 12117     0.009654    -0.450332 -0.577916     0.284130  -0.628775
# ...            ...          ...       ...          ...        ...
# 11964     0.009654     0.402913  0.081815     0.284130   0.658317
# 5191      0.009654     0.402913  0.081815     0.284130   1.958284
# 5390      0.009654    -0.450332  0.081815    -1.106492  -0.124481
# 860       0.009654     0.402913  0.081815     0.284130  -0.111781
# 7270      0.009654     0.402913  0.081815     0.284130  -0.628775
#
#        response_woe
# 10678     -0.280460
# 5635      -0.280460
# 9343       0.431817
# 4581      -0.280460
# 12117     -0.280460
# ...             ...
# 11964      0.431817
# 5191      -0.280460
# 5390      -0.280460
# 860       -0.280460
# 7270      -0.280460
#
# [9009 rows x 11 columns]

# %%
test_data.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'pdays',
#        'previous', 'response'],
#       dtype='object')

# %%
test_data = test_data[['ID','balance','campaign','job','marital','education','default','housing','loan','contact','month','response']]
test_data
# Out:
#       ID  balance  campaign          job   marital  education default housing  \
# 0    812      764         1  blue-collar    single  secondary      no     yes
# 1     71      118         1  blue-collar    single    primary      no      no
# 2    912      451         1       admin.  divorced  secondary      no     yes
# 3     43      495         1     services    single  secondary      no     yes
# 4    431     1548         2  blue-collar   married    primary      no     yes
# ..   ...      ...       ...          ...       ...        ...     ...     ...
# 852   49      413         2  blue-collar   married  secondary      no     yes
# 853  409     1282         4   management   married   tertiary      no      no
# 854  105      976         3       admin.   married    primary      no     yes
# 855  810     1159         1   unemployed    single   tertiary      no      no
# 856  410     1860         3  blue-collar   married  secondary      no      no
#
#     loan    contact month response
# 0     no   cellular   may  unknown
# 1     no    unknown   feb  unknown
# 2     no   cellular   jul  unknown
# 3     no   cellular   nov  unknown
# 4    yes   cellular   may  unknown
# ..   ...        ...   ...      ...
# 852   no   cellular   aug  success
# 853   no   cellular   aug  unknown
# 854   no    unknown   jun  unknown
# 855   no  telephone   jun  unknown
# 856   no    unknown   jun  unknown
#
# [857 rows x 12 columns]

# %%
data
# Out:
#           ID  age         job  marital  education default   balance housing  \
# 0      13829   29  technician   single   tertiary      no  3826.375      no
# 1      22677   26    services   single  secondary      no   512.000     yes
# 2      10541   30  management   single  secondary      no   135.000      no
# 3      13689   41  technician  married    unknown      no    30.000     yes
# 4      11304   27      admin.   single  secondary      no   321.000      no
# ...      ...  ...         ...      ...        ...     ...       ...     ...
# 12865  14023   47  technician  married  secondary      no  1167.000     yes
# 12866  17259   31     unknown  married  secondary      no   111.000      no
# 12867  15200   37  unemployed   single   tertiary      no  1316.000     yes
# 12868  13775   42  management  married   tertiary      no   479.000     yes
# 12869  20137   24    services   single  secondary      no     0.000      no
#
#       loan   contact  day month  campaign response  result  balance_category  \
# 0       no  cellular   11   may       2.0  unknown       1    (1591.75, inf]
# 1      yes   unknown    5   jun       3.0  unknown       1    (102.0, 515.0]
# 2       no  cellular   14   aug       2.0  unknown       1    (102.0, 515.0]
# 3       no  cellular   10   jul       1.0  unknown       1     (-inf, 102.0]
# 4      yes   unknown    2   sep       1.0  unknown       1    (102.0, 515.0]
# ...    ...       ...  ...   ...       ...      ...     ...               ...
# 12865   no  cellular   30   apr       1.0  failure       0  (515.0, 1591.75]
# 12866   no  cellular   21   nov       2.0  failure       0    (102.0, 515.0]
# 12867   no  cellular   18   nov       1.0  failure       1  (515.0, 1591.75]
# 12868   no   unknown   28   may       2.0  unknown       1    (102.0, 515.0]
# 12869   no   unknown   16   may       1.0  unknown       1     (-inf, 102.0]
#
#        balance_woe campaign_category  campaign_woe   job_woe  marital_woe  \
# 0         0.396176        (1.0, 2.0]     -0.010317 -0.066429     0.275227
# 1        -0.036100        (2.0, 3.0]     -0.050576 -0.223585     0.275227
# 2        -0.036100        (1.0, 2.0]     -0.010317  0.161072     0.275227
# 3        -0.493008       (-inf, 1.0]      0.247182 -0.066429    -0.168233
# 4        -0.036100       (-inf, 1.0]      0.247182  0.018331     0.275227
# ...            ...               ...           ...       ...          ...
# 12865     0.056321       (-inf, 1.0]      0.247182 -0.066429    -0.168233
# 12866    -0.036100        (1.0, 2.0]     -0.010317  0.019921    -0.168233
# 12867     0.056321       (-inf, 1.0]      0.247182  0.284649     0.275227
# 12868    -0.036100        (1.0, 2.0]     -0.010317  0.161072    -0.168233
# 12869    -0.493008       (-inf, 1.0]      0.247182 -0.223585     0.275227
#
#        education_woe  default_woe  housing_woe  loan_woe  contact_woe  \
# 0           0.284837     0.009654     0.402913  0.081815     0.284130
# 1          -0.112864     0.009654    -0.450332 -0.577916    -1.106492
# 2          -0.112864     0.009654     0.402913  0.081815     0.284130
# 3           0.112487     0.009654    -0.450332  0.081815     0.284130
# 4          -0.112864     0.009654     0.402913 -0.577916    -1.106492
# ...              ...          ...          ...       ...          ...
# 12865      -0.112864     0.009654    -0.450332  0.081815     0.284130
# 12866      -0.112864     0.009654     0.402913  0.081815     0.284130
# 12867       0.284837     0.009654    -0.450332  0.081815     0.284130
# 12868       0.284837     0.009654    -0.450332  0.081815    -1.106492
# 12869      -0.112864     0.009654     0.402913  0.081815    -1.106492
#
#        month_woe  response_woe
# 0      -0.628775     -0.280460
# 1      -0.124481     -0.280460
# 2      -0.111781     -0.280460
# 3      -0.248969     -0.280460
# 4       1.839980     -0.280460
# ...          ...           ...
# 12865   0.658317      0.173374
# 12866  -0.146627      0.173374
# 12867  -0.146627      0.173374
# 12868  -0.628775     -0.280460
# 12869  -0.628775     -0.280460
#
# [12870 rows x 28 columns]

# %%
data.balance_category.value_counts()
# Out:
# (-inf, 102.0]       3230
# (1591.75, inf]      3218
# (515.0, 1591.75]    3215
# (102.0, 515.0]      3207
# Name: balance_category, dtype: int64

# %%
ranges = [-np.inf, 102.0, 515.0, 1591.75, np.inf]
test_data['balance_category'] = pd.cut(test_data['balance'], bins=ranges)
# Out:
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/583336966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['balance_category'] = pd.cut(test_data['balance'], bins=ranges)

# %%
data.campaign_category.value_counts()
# Out:
# (-inf, 1.0]    5222
# (1.0, 2.0]     3493
# (3.0, inf]     2599
# (2.0, 3.0]     1556
# Name: campaign_category, dtype: int64

# %%
ranges = [-np.inf, 1.0, 2.0, 3.0, np.inf]
test_data['campaign_category'] = pd.cut(test_data['campaign'], bins=ranges)
# Out:
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/4163733591.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['campaign_category'] = pd.cut(test_data['campaign'], bins=ranges)

# %%
test_data = test_data.merge(data[['balance_category','balance_woe']].drop_duplicates(subset='balance_category'), how='left', on='balance_category')
test_data = test_data.merge(data[['campaign_category','campaign_woe']].drop_duplicates(subset='campaign_category'),how='left', on='campaign_category')

# %%
#test_data

# %%
test_data = test_data.merge(data[['job','job_woe']].drop_duplicates(subset='job'), how='left', on='job')
test_data = test_data.merge(data[['marital','marital_woe']].drop_duplicates(subset='marital'), how='left', on='marital')
test_data = test_data.merge(data[['education','education_woe']].drop_duplicates(subset='education'), how='left', on='education')
test_data = test_data.merge(data[['default','default_woe']].drop_duplicates(subset='default'), how='left', on='default')
test_data = test_data.merge(data[['housing','housing_woe']].drop_duplicates(subset='housing'), how='left', on='housing')
test_data = test_data.merge(data[['loan','loan_woe']].drop_duplicates(subset='loan'), how='left', on='loan')
test_data = test_data.merge(data[['contact','contact_woe']].drop_duplicates(subset='contact'), how='left', on='contact')
test_data = test_data.merge(data[['month','month_woe']].drop_duplicates(subset='month'), how='left', on='month')
test_data = test_data.merge(data[['response','response_woe']].drop_duplicates(subset='response'), how='left', on='response')

test_data
# Out:
#       ID  balance  campaign          job   marital  education default housing  \
# 0    812      764         1  blue-collar    single  secondary      no     yes
# 1     71      118         1  blue-collar    single    primary      no      no
# 2    912      451         1       admin.  divorced  secondary      no     yes
# 3     43      495         1     services    single  secondary      no     yes
# 4    431     1548         2  blue-collar   married    primary      no     yes
# ..   ...      ...       ...          ...       ...        ...     ...     ...
# 852   49      413         2  blue-collar   married  secondary      no     yes
# 853  409     1282         4   management   married   tertiary      no      no
# 854  105      976         3       admin.   married    primary      no     yes
# 855  810     1159         1   unemployed    single   tertiary      no      no
# 856  410     1860         3  blue-collar   married  secondary      no      no
#
#     loan    contact month response  balance_category campaign_category  \
# 0     no   cellular   may  unknown  (515.0, 1591.75]       (-inf, 1.0]
# 1     no    unknown   feb  unknown    (102.0, 515.0]       (-inf, 1.0]
# 2     no   cellular   jul  unknown    (102.0, 515.0]       (-inf, 1.0]
# 3     no   cellular   nov  unknown    (102.0, 515.0]       (-inf, 1.0]
# 4    yes   cellular   may  unknown  (515.0, 1591.75]        (1.0, 2.0]
# ..   ...        ...   ...      ...               ...               ...
# 852   no   cellular   aug  success    (102.0, 515.0]        (1.0, 2.0]
# 853   no   cellular   aug  unknown  (515.0, 1591.75]        (3.0, inf]
# 854   no    unknown   jun  unknown  (515.0, 1591.75]        (2.0, 3.0]
# 855   no  telephone   jun  unknown  (515.0, 1591.75]       (-inf, 1.0]
# 856   no    unknown   jun  unknown    (1591.75, inf]        (2.0, 3.0]
#
#      balance_woe  campaign_woe   job_woe  marital_woe  education_woe  \
# 0       0.056321      0.247182 -0.551866     0.275227      -0.112864
# 1      -0.036100      0.247182 -0.551866     0.275227      -0.330354
# 2      -0.036100      0.247182  0.018331     0.060831      -0.112864
# 3      -0.036100      0.247182 -0.223585     0.275227      -0.112864
# 4       0.056321     -0.010317 -0.551866    -0.168233      -0.330354
# ..           ...           ...       ...          ...            ...
# 852    -0.036100     -0.010317 -0.551866    -0.168233      -0.112864
# 853     0.056321     -0.534710  0.161072    -0.168233       0.284837
# 854     0.056321     -0.050576  0.018331    -0.168233      -0.330354
# 855     0.056321      0.247182  0.284649     0.275227       0.284837
# 856     0.396176     -0.050576 -0.551866    -0.168233      -0.112864
#
#      default_woe  housing_woe  loan_woe  contact_woe  month_woe  response_woe
# 0       0.009654    -0.450332  0.081815     0.284130  -0.628775     -0.280460
# 1       0.009654     0.402913  0.081815    -1.106492   0.430915     -0.280460
# 2       0.009654    -0.450332  0.081815     0.284130  -0.248969     -0.280460
# 3       0.009654    -0.450332  0.081815     0.284130  -0.146627     -0.280460
# 4       0.009654    -0.450332 -0.577916     0.284130  -0.628775     -0.280460
# ..           ...          ...       ...          ...        ...           ...
# 852     0.009654    -0.450332  0.081815     0.284130  -0.111781      2.549958
# 853     0.009654     0.402913  0.081815     0.284130  -0.111781     -0.280460
# 854     0.009654    -0.450332  0.081815    -1.106492  -0.124481     -0.280460
# 855     0.009654     0.402913  0.081815     0.132325  -0.124481     -0.280460
# 856     0.009654     0.402913  0.081815    -1.106492  -0.124481     -0.280460
#
# [857 rows x 25 columns]

# %%
data.isnull().sum()
# Out:
# ID                   0
# age                  0
# job                  0
# marital              0
# education            0
# default              0
# balance              0
# housing              0
# loan                 0
# contact              0
# day                  0
# month                0
# campaign             0
# response             0
# result               0
# balance_category     0
# balance_woe          0
# campaign_category    0
# campaign_woe         0
# job_woe              0
# marital_woe          0
# education_woe        0
# default_woe          0
# housing_woe          0
# loan_woe             0
# contact_woe          0
# month_woe            0
# response_woe         0
# dtype: int64

# %%
test_data.columns
# Out:
# Index(['ID', 'balance', 'campaign', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'month', 'response', 'balance_category',
#        'campaign_category', 'balance_woe', 'campaign_woe', 'job_woe',
#        'marital_woe', 'education_woe', 'default_woe', 'housing_woe',
#        'loan_woe', 'contact_woe', 'month_woe', 'response_woe'],
#       dtype='object')

# %%
test_data_woe = test_data[['ID','balance_woe', 'campaign_woe', 'job_woe',
       'marital_woe', 'education_woe', 'default_woe', 'housing_woe',
       'loan_woe', 'contact_woe', 'month_woe', 'response_woe']]
test_data_woe
# Out:
#       ID  balance_woe  campaign_woe   job_woe  marital_woe  education_woe  \
# 0    812     0.056321      0.247182 -0.551866     0.275227      -0.112864
# 1     71    -0.036100      0.247182 -0.551866     0.275227      -0.330354
# 2    912    -0.036100      0.247182  0.018331     0.060831      -0.112864
# 3     43    -0.036100      0.247182 -0.223585     0.275227      -0.112864
# 4    431     0.056321     -0.010317 -0.551866    -0.168233      -0.330354
# ..   ...          ...           ...       ...          ...            ...
# 852   49    -0.036100     -0.010317 -0.551866    -0.168233      -0.112864
# 853  409     0.056321     -0.534710  0.161072    -0.168233       0.284837
# 854  105     0.056321     -0.050576  0.018331    -0.168233      -0.330354
# 855  810     0.056321      0.247182  0.284649     0.275227       0.284837
# 856  410     0.396176     -0.050576 -0.551866    -0.168233      -0.112864
#
#      default_woe  housing_woe  loan_woe  contact_woe  month_woe  response_woe
# 0       0.009654    -0.450332  0.081815     0.284130  -0.628775     -0.280460
# 1       0.009654     0.402913  0.081815    -1.106492   0.430915     -0.280460
# 2       0.009654    -0.450332  0.081815     0.284130  -0.248969     -0.280460
# 3       0.009654    -0.450332  0.081815     0.284130  -0.146627     -0.280460
# 4       0.009654    -0.450332 -0.577916     0.284130  -0.628775     -0.280460
# ..           ...          ...       ...          ...        ...           ...
# 852     0.009654    -0.450332  0.081815     0.284130  -0.111781      2.549958
# 853     0.009654     0.402913  0.081815     0.284130  -0.111781     -0.280460
# 854     0.009654    -0.450332  0.081815    -1.106492  -0.124481     -0.280460
# 855     0.009654     0.402913  0.081815     0.132325  -0.124481     -0.280460
# 856     0.009654     0.402913  0.081815    -1.106492  -0.124481     -0.280460
#
# [857 rows x 12 columns]

# %%
prob = optimized_model.predict_proba(test_data_woe.iloc[:,1:])[:,1]

# %%
test_data_woe['PD'] = prob
test_data_woe
# Out:
# /var/folders/vp/sgk1_hlx22xd7xk0vzygtjr80000gn/T/ipykernel_2222/2561058433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data_woe['PD'] = prob
#       ID  balance_woe  campaign_woe   job_woe  marital_woe  education_woe  \
# 0    812     0.056321      0.247182 -0.551866     0.275227      -0.112864
# 1     71    -0.036100      0.247182 -0.551866     0.275227      -0.330354
# 2    912    -0.036100      0.247182  0.018331     0.060831      -0.112864
# 3     43    -0.036100      0.247182 -0.223585     0.275227      -0.112864
# 4    431     0.056321     -0.010317 -0.551866    -0.168233      -0.330354
# ..   ...          ...           ...       ...          ...            ...
# 852   49    -0.036100     -0.010317 -0.551866    -0.168233      -0.112864
# 853  409     0.056321     -0.534710  0.161072    -0.168233       0.284837
# 854  105     0.056321     -0.050576  0.018331    -0.168233      -0.330354
# 855  810     0.056321      0.247182  0.284649     0.275227       0.284837
# 856  410     0.396176     -0.050576 -0.551866    -0.168233      -0.112864
#
#      default_woe  housing_woe  loan_woe  contact_woe  month_woe  response_woe  \
# 0       0.009654    -0.450332  0.081815     0.284130  -0.628775     -0.280460
# 1       0.009654     0.402913  0.081815    -1.106492   0.430915     -0.280460
# 2       0.009654    -0.450332  0.081815     0.284130  -0.248969     -0.280460
# 3       0.009654    -0.450332  0.081815     0.284130  -0.146627     -0.280460
# 4       0.009654    -0.450332 -0.577916     0.284130  -0.628775     -0.280460
# ..           ...          ...       ...          ...        ...           ...
# 852     0.009654    -0.450332  0.081815     0.284130  -0.111781      2.549958
# 853     0.009654     0.402913  0.081815     0.284130  -0.111781     -0.280460
# 854     0.009654    -0.450332  0.081815    -1.106492  -0.124481     -0.280460
# 855     0.009654     0.402913  0.081815     0.132325  -0.124481     -0.280460
# 856     0.009654     0.402913  0.081815    -1.106492  -0.124481     -0.280460
#
#            PD
# 0    0.632908
# 1    0.836975
# 2    0.552062
# 3    0.597991
# 4    0.825956
# ..        ...
# 852  0.215647
# 853  0.736966
# 854  0.913848
# 855  0.470334
# 856  0.874781
#
# [857 rows x 13 columns]
